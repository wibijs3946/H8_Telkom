# %%
# Sesi 5

# %%
## Sesi 5

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv(./nbaallelo.csv)
# Out:
#   File "<ipython-input-44-7b43700a0b72>", line 1
#     df = pd.read_csv(./nbaallelo.csv)
#                      ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv(''./nbaallelo.csv')

# %%
df = pd.read_csv('./nbaallelo.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
pd.set_option('display.max.columns', None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
pd.set_option('display.precision', 2)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.tail)
# Out:
#   File "<ipython-input-54-cf4b28c3379c>", line 1
#     df.tail)
#            ^
# SyntaxError: invalid syntax

# %%
df.tail()

# %%
df.head(10)

# %%
df.info()

# %%
df.describe()

# %%
df['team_id'].value_counts()

# %%
df['fran_id'].value_counts()

# %%
df['fran_id'].value.counts()

# %%
df.loc[df['fran_id'] == 'Lakers'].value_counts()

# %%
df.loc[df['fran_id'] == 'Lakers']

# %%
df.loc[df['fran_id'] == 'Lakers', 'team_id'].value_counts()

# %%
df.loc[df['team_id'] == 'MNL', 'date_game']

# %%
df.loc[df['team_id'] == 'MNL', 'year_id'].min()

# %%
df.loc[df['team_id'] == 'MNL', 'year_id'].max()

# %%
df.info()

# %%
df.loc[df['team_id'] == 'MNL', 'year_id'].agg(('min','max'))

# %%
df.info()

# %%
df.loc[df['team_id'] == 'BOS', 'pts'].sum()
# Out:
# 626484

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=['Amsterdam', 'Toronto', 'Tokyo']
)

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({'Amsterdam': 5, 'Tokyo': 8})

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
##DataFrame

# %%
## DataFrame

# %%
city_data = pd.DataFrame({
    'revenue': city_revenues,
    'employee_count': city_employee_count
})

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
## Accessing Series Elements

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues['Toronto']
# Out:
# 8000

# %%
city_revenues[1]
# Out:
# 8000

# %%
colors = pd.Series(
    ['red', 'purple', 'blue', 'green', 'yellow'],
    index = [1,2,3,5,8]
)

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors[1]
# Out:
# 'red'

# %%
colors[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-4f7c25fbc5d6> in <module>
# ----> 1 colors[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
# ...

# %%
colors.loc[1]
# Out:
# 'red'

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
colors.loc[1:3]
# Out:
# 1       red
# 2    purple
# 3      blue
# dtype: object

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
## Accessing DataFrame Elements

# %%
city_data['revenue']
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape": "sphere"},
    {"name": "Rubik's cube", "shape": "cube"}
])

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
df.loc[2000:2005]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 2000       1001  194911150INO   NBA        1     1950 1949-11-15           6
# 2001       1001  194911150INO   NBA        0     1950 1949-11-15           8
# 2002       1002  194911150NYK   NBA        0     1950 1949-11-15          10
# 2003       1002  194911150NYK   NBA        1     1950 1949-11-15           8
# 2004       1003  194911150ROC   NBA        0     1950 1949-11-15           6
# 2005       1003  194911150ROC   NBA        1     1950 1949-11-15           7
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 2000            0     AND    Packers   83  1557.80  1564.48      52.55    INO
# 2001            0     INO  Olympians   72  1336.96  1330.27      28.70    AND
# 2002            0     NYK     Knicks   74  1459.54  1453.01      41.18    SYR
# 2003            0     SYR     Sixers   77  1515.50  1522.02      48.34    NYK
# ...

# %%
df.loc[2000:2005, ['fran_id', 'opp_fran', 'pts', 'opp_pts']]
# Out:
#         fran_id   opp_fran  pts  opp_pts
# 2000    Packers  Olympians   83       72
# 2001  Olympians    Packers   72       83
# 2002     Knicks     Sixers   74       77
# 2003     Sixers     Knicks   77       74
# 2004      Kings      Hawks   93       81
# 2005      Hawks      Kings   81       93

# %%
df.shape
# Out:
# (126314, 23)

# %%
current_decades = df[df['year_id'] > 2010]

# %%
current_decades
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# 113661      56831  201010260POR   NBA        0     2011  10/26/2010
# 113662      56832  201010270CLE   NBA        0     2011  10/27/2010
# 113663      56832  201010270CLE   NBA        1     2011  10/27/2010
# 113664      56833  201010270DAL   NBA        1     2011  10/27/2010
# 113665      56833  201010270DAL   NBA        0     2011  10/27/2010
# 113666      56834  201010270DEN   NBA        0     2011  10/27/2010
# 113667      56834  201010270DEN   NBA        1     2011  10/27/2010
# 113668      56835  201010270GSW   NBA        0     2011  10/27/2010
# ...

# %%
games_with_notes = df[df['notes'].notnull()]

# %%
games_with_notes.shape
# Out:
# (5424, 23)

# %%
df[
    (df['year_id'] > 2015) &
    (df['pts'] >100) &
    (df['opp_pts'] > 100)
]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %%
df.shape
# Out:
# (126314, 23)

# %%
df[
    (df['year_id'] > 2015) &
    (df['pts'] >100) &
    (df['opp_pts'] > 100)
]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %%
df[
    (df['year_id'] >= 2015) &
    (df['pts'] >100) &
    (df['opp_pts'] > 100)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 123698      61850  201410290BOS   NBA        0     2015  10/29/2014
# 123699      61850  201410290BOS   NBA        1     2015  10/29/2014
# 123700      61851  201410290CHO   NBA        1     2015  10/29/2014
# 123701      61851  201410290CHO   NBA        0     2015  10/29/2014
# 123706      61854  201410290MEM   NBA        0     2015  10/29/2014
# 123707      61854  201410290MEM   NBA        1     2015  10/29/2014
# 123718      61860  201410290TOR   NBA        0     2015  10/29/2014
# 123719      61860  201410290TOR   NBA        1     2015  10/29/2014
# 123724      61863  201410300DAL   NBA        1     2015  10/30/2014
# 123725      61863  201410300DAL   NBA        0     2015  10/30/2014
# 123732      61867  201410310CHI   NBA        0     2015  10/31/2014
# 123733      61867  201410310CHI   NBA        1     2015  10/31/2014
# 123736      61869  201410310LAL   NBA        1     2015  10/31/2014
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %%
nba.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-38871bab7fd4> in <module>
# ----> 1 nba.info
#
# NameError: name 'nba' is not defined

# %%
df.info
# Out:
# <bound method DataFrame.info of         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null object
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null object
# game_result      126314 non-null object
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba = df

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null object
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null object
# game_result      126314 non-null object
# ...

# %%
nba['date_game'] = pd.to_datetime(['date_game'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-68faa1e0b917> in <module>
# ----> 1 nba['date_game'] = pd.to_datetime(['date_game'])
#
# ...

# %%
nba['date_game'] = pd.to_datetime(nba['date_game'])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null datetime64[ns]
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null object
# ...

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba['game_location'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         H
# 1         A
# 2         H
# 3         A
# 4         H
# 5         A
# 6         A
# 7         H
# 8         A
# 9         H
# 10        A
# 11        H
# 12        H
# 13        A
# 14        H
# 15        A
# 16        A
# 17        H
# 18        A
# 19        H
# 20        H
# 21        A
# 22        H
# 23        A
# 24        H
# 25        A
# 26        A
# 27        H
# 28        A
# 29        H
#          ..
# 126284    H
# 126285    A
# 126286    H
# 126287    A
# 126288    H
# 126289    A
# 126290    H
# 126291    A
# 126292    A
# 126293    H
# 126294    H
# 126295    A
# 126296    A
# 126297    H
# 126298    H
# 126299    A
# 126300    A
# 126301    H
# 126302    A
# 126303    H
# 126304    A
# 126305    H
# 126306    A
# 126307    H
# 126308    A
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: game_location, Length: 126314, dtype: object>

# %%
nba['game_location'].nunique()
# Out:
# 3

# %%
nba['game_location'].values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-76343acd168b> in <module>
# ----> 1 nba['game_location'].values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
nba['game_location'].value_counts()
# Out:
# A    63138
# H    63138
# N       38
# Name: game_location, dtype: int64

# %%
pd.date_range('2020-10-28', freq='H')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-e73fa8072836> in <module>
# ----> 1 pd.date_range('2020-10-28', freq='H')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#    1522         start=start, end=end, periods=periods,
#    1523         freq=freq, tz=tz, normalize=normalize,
# -> 1524         closed=closed, **kwargs)
#    1525     return DatetimeIndex._simple_new(
#    1526         dtarr, tz=dtarr.tz, freq=dtarr.freq, name=name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, closed)
#     404
#     405         if com.count_not_none(start, end, periods, freq) != 3:
# ...

# %%
pd.Categorical(nba['game_location'])
# Out:
# [H, A, H, A, H, ..., H, H, A, H, A]
# Length: 126314
# Categories (3, object): [A, H, N]

# %%
nba['game_location'] = pd.Categorical(nba['game_location'])

# %%
nba.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-c9ee75ac7a9a> in <module>
# ----> 1 nba.shape()
#
# TypeError: 'tuple' object is not callable

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null datetime64[ns]
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null category
# ...

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# 5               3  194611020DTF   NBA        1     1947 1946-11-02
# 6               4  194611020PRO   NBA        1     1947 1946-11-02
# 7               4  194611020PRO   NBA        0     1947 1946-11-02
# 8               5  194611020STB   NBA        1     1947 1946-11-02
# 9               5  194611020STB   NBA        0     1947 1946-11-02
# 10              6  194611030CLR   NBA        1     1947 1946-11-03
# 11              6  194611030CLR   NBA        0     1947 1946-11-03
# 12              7  194611040PIT   NBA        0     1947 1946-11-04
# ...

# %%
nba.shape
# Out:
# (126314, 23)

# %%
rows_without_missing_data = nba.dropna()

# %%
rows_without_missing_data.shape
# Out:
# (5424, 23)

# %%
data_without_missing_columns = nba.dropna(axis=1)

# %%
data_without_missing_columns.shape
# Out:
# (126314, 22)

# %%
further_city_data = pd.DataFrame(
    {'revenue': [7000, 3400],
    'employee_count': [2,2]},
    index=['New York', 'Barcelona']
)

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-39ac7a9853bf> in <module>
# ----> 1 city_data
#
# NameError: name 'city_data' is not defined

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False)

# %%
city_countries = pd.DataFrame({
    'country': ['Holland', 'Japan', 'Holland', 'Canada', 'Spain'],
    'capital': [1, 1, 0, 0, 0]},
    index = ['Amsterdam', 'Tokyo', 'Rotterdam', 'Toronto', 'Barcelona']
)

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
pd.concat([all_city_data, city_countries], axis=1, sort=False)
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
pd.concat([city_countries, all_city_data], axis=1, sort=False)
# Out:
#            country  capital  revenue  employee_count
# Amsterdam  Holland      1.0   4200.0             5.0
# Tokyo        Japan      1.0   6500.0             8.0
# Rotterdam  Holland      0.0      NaN             NaN
# Toronto     Canada      0.0   8000.0             NaN
# Barcelona    Spain      0.0   3400.0             2.0
# New York       NaN      NaN   7000.0             2.0

# %%
pd.concat([city_countries, all_city_data], axis=1, join='inner', sort=False)
# Out:
#            country  capital  revenue  employee_count
# Amsterdam  Holland        1     4200             5.0
# Tokyo        Japan        1     6500             8.0
# Toronto     Canada        0     8000             NaN
# Barcelona    Spain        0     3400             2.0

# %%
pd.concat([city_countries, all_city_data], axis=1, join='inner')
# Out:
#            country  capital  revenue  employee_count
# Amsterdam  Holland        1     4200             5.0
# Tokyo        Japan        1     6500             8.0
# Toronto     Canada        0     8000             NaN
# Barcelona    Spain        0     3400             2.0

# %%
pd.concat([city_countries, all_city_data], axis=1, join='inner', sort=True)
# Out:
#            country  capital  revenue  employee_count
# Amsterdam  Holland        1     4200             5.0
# Barcelona    Spain        0     3400             2.0
# Tokyo        Japan        1     6500             8.0
# Toronto     Canada        0     8000             NaN

# %%
pd.concat([city_countries, all_city_data], axis=0, join='inner', sort=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Amsterdam, Tokyo, Rotterdam, Toronto, Barcelona, Amsterdam, Tokyo, Toronto, New York, Barcelona]

# %%
pd.concat([city_countries, all_city_data], axis=0, sort=True)
# Out:
#            capital  country  employee_count  revenue
# Amsterdam      1.0  Holland             NaN      NaN
# Tokyo          1.0    Japan             NaN      NaN
# Rotterdam      0.0  Holland             NaN      NaN
# Toronto        0.0   Canada             NaN      NaN
# Barcelona      0.0    Spain             NaN      NaN
# Amsterdam      NaN      NaN             5.0   4200.0
# Tokyo          NaN      NaN             8.0   6500.0
# Toronto        NaN      NaN             NaN   8000.0
# New York       NaN      NaN             2.0   7000.0
# Barcelona      NaN      NaN             2.0   3400.0

# %%
cities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-65ba5a9af2c6> in <module>
# ----> 1 cities
#
# NameError: name 'cities' is not defined

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
countries = pd.DataFrame({
    'population_millions': [17,127,37],
})

# %%
countries = pd.DataFrame({
    'population_millions': [17,127,37],
    'continent':['Europe', 'Asia', 'North America']},
    index = ['Holland', 'Japan', 'Canada']
)

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
## Visualizing Pandas DataFrame

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# 5               3  194611020DTF   NBA        1     1947 1946-11-02
# 6               4  194611020PRO   NBA        1     1947 1946-11-02
# 7               4  194611020PRO   NBA        0     1947 1946-11-02
# 8               5  194611020STB   NBA        1     1947 1946-11-02
# 9               5  194611020STB   NBA        0     1947 1946-11-02
# 10              6  194611030CLR   NBA        1     1947 1946-11-03
# 11              6  194611030CLR   NBA        0     1947 1946-11-03
# 12              7  194611040PIT   NBA        0     1947 1946-11-04
# ...

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba[
    nba['fran_id'] == 'Knicks'
].groupby('year_id')['pts'].sum().plot()

# %%
from IPython.core.interactiveshell import InteractiveShell

# %%
InteractiveShell.ast_node_interactivity = "all"

# %%
nba[
    nba['fran_id'] == 'Knicks'
].groupby('year_id')['pts'].sum().plot()

# %%
nba['fran_id'].value_counts().plot(kind='bar')
